# %%
with open("day16.txt", "r") as f:
    data = f.read()

# %%
lines = data.split("\n")

# %%
pattern = []
for line in lines:
    row = []
    for char in line:
        row.append(char)
    pattern.append(row)

# %%
pattern
# Out:
# [['\\',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.'],
#  ['-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '/',
#   '|',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '\\',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '|',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '\\',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '|',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['-',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['\\',
#   '-',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '|',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '|',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '\\',
#   '.',
#   '.'],
#  ['.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '-',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '-',
#   '|',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|'],
#  ['.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '\\'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['-',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '\\',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '\\',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '|',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '-',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '|',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '-'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
# ...
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.'],
#  ['.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '/',
#   '.',
#   '\\',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.'],
#  ['.',
#   '|',
#   '.',
#   '.',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '-',
#   '-',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '-',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '/',
#   '-',
#   '.',
#   '/',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '/',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '|',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '/',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '|',
#   '.',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '-',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.'],
#  ['.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '.',
#   '.',
#   '|',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '\\',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '|',
#   '/',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.']]

# %%
energized = []
for row in range(len(pattern)):
    energized_row = []
    for col in range(len(pattern[row])):
        energized_row.append(0)
    energized.append(energized_row)

# %%
def get_next_beams(beam_row, beam_col, direction, char):
    if char == '.':
        # keep going
        if direction == "right":
            return [(beam_row, beam_col + 1, direction)]
        elif direction == "left":
            return [(beam_row, beam_col - 1, direction)]
        elif direction == "up":
            return [(beam_row - 1, beam_col, direction)]
        elif direction == "down":
            return [(beam_row + 1, beam_col, direction)]
    elif char == '/':
        # need do reflect
        if direction == "right":
            return [(beam_row - 1, beam_col, "up")]
        elif direction == "left":
            return [(beam_row + 1, beam_col, "down")]
        elif direction == "up":
            return [(beam_row, beam_col + 1, "right")]
        elif direction == "down":
            return [(beam_row, beam_col - 1, "left")]
    elif char == '\\':
        # also reflect
        if direction == "right":
            return [(beam_row + 1, beam_col, "down")]
        elif direction == "left":
            return [(beam_row - 1, beam_col, "up")]
        elif direction == "up":
            return [(beam_row, beam_col - 1, "left")]
        elif direction == "down":
            return [(beam_row, beam_col + 1, "right")]
    elif char == '|':
        # point side: keep going
        # flat side: split
        if direction == "right" or direction == "left":
            return [(beam_row + 1, beam_col, "down"), (beam_row - 1, beam_col, "up")]
        elif direction == 'up':
            return [(beam_row - 1, beam_col, "up")]
        elif direction == 'down':
            return [(beam_row + 1, beam_col, "down")]
    elif char == '-':
        if direction == "up" or direction == "down":
            return [(beam_row, beam_col + 1, "right"), (beam_row, beam_col - 1, "left")]
        elif direction == 'right':
            return [(beam_row, beam_col + 1, "right")]
        elif direction == 'left':
            return [(beam_row, beam_col - 1, "left")]
    raise Exception("Unknown char: " + char)

# %%
def get_next_position(beam_row, beam_col, direction):
    if direction == "right":
        return (beam_row, beam_col + 1)
    elif direction == "left":
        return (beam_row, beam_col - 1)
    elif direction == "up":
        return (beam_row - 1, beam_col)
    elif direction == "down":
        return (beam_row + 1, beam_col)

# %%
def get_next_position_until_special_char(beam_row, beam_col, direction, pattern, energized):

    cur_row, cur_col = beam_row, beam_col
    while True:
        energized[cur_row][cur_col] += 1
        cur_row, cur_col = get_next_position(cur_row, cur_col, direction)
        # check border
        if cur_row < 0 or cur_row >= len(pattern):
            return None
        if cur_col < 0 or cur_col >= len(pattern[cur_row]):
            return None
        
        # until special char
        if pattern[cur_row][cur_col] in ['|', '-', '/', '\\']:
            return (cur_row, cur_col)

# %%
def count_number_of_non_zero(energized):
    count = 0
    for row in range(len(energized)):
        for col in range(len(energized[row])):
            if energized[row][col] != 0:
                count += 1
    return count

# %%
edge_start_beams = []
# top
for idx in range(len(pattern[0])):
    edge_start_beams.append((0, idx, "down"))
# bottom
for idx in range(len(pattern[-1])):
    edge_start_beams.append((len(pattern) - 1, idx, "up"))
# left
for idx in range(len(pattern)):
    edge_start_beams.append((idx, 0, "right"))
# right
for idx in range(len(pattern)):
    edge_start_beams.append((idx, len(pattern[0]) - 1, "left"))

# %%
edge_energized = []

for outer_idx, edge_start_beam in enumerate(edge_start_beams):
    print("calculating edge: ", outer_idx, edge_start_beam)
    energized = []
    for row in range(len(pattern)):
        energized_row = []
        for col in range(len(pattern[row])):
            energized_row.append(0)
        energized.append(energized_row)

    beams = [edge_start_beam]
    traced_beams = []
    sim_step = 0
    current_energized = 0

    while len(beams) > 0 and sim_step <= 100000:
        sim_step += 1
        last_energized = current_energized
        current_beam = beams.pop(0)
        beam_row, beam_col, direction = current_beam
        if sim_step % 1000 == 0:
            print("step: " + str(sim_step) + " beam: " + str(current_beam) + " direction: " + direction, "len beam", len(beams))
        # print("step: " + str(sim_step) + " beam: " + str(current_beam) + " direction: " + direction, "len beam", len(beams))
        # out of border, ignore
        if beam_row < 0 or beam_row >= len(pattern):
            # print("out of border", beam_row, beam_col, direction)
            continue
        if beam_col < 0 or beam_col >= len(pattern[beam_row]):
            # print("out of border", beam_row, beam_col, direction)
            continue
        
        energized[beam_row][beam_col] += 1

        next_char = pattern[beam_row][beam_col]
        next_beams = get_next_beams(beam_row, beam_col, direction, next_char)
        # print("next beams: " + str(next_beams))

        for next_beam in next_beams:
            if next_beam in traced_beams:
                continue
            else:
                traced_beams.append(next_beam)
                beams.append(next_beam)

        current_energized = count_number_of_non_zero(energized)
        # print("current energized: " + str(current_energized), "last energized: " + str(last_energized))
    
    edge_energized.append(current_energized)
    print("calculating edge: ", outer_idx, edge_start_beam, "done, energized=", current_energized)
# Out:
# calculating edge:  0 (0, 0, 'down')
# calculating edge:  0 (0, 0, 'down') done, energized= 64
# calculating edge:  1 (0, 1, 'down')
# step: 1000 beam: (8, 29, 'up') direction: up len beam 8
# step: 2000 beam: (81, 73, 'up') direction: up len beam 18
# step: 3000 beam: (70, 60, 'down') direction: down len beam 36
# step: 4000 beam: (63, 70, 'right') direction: right len beam 39
# step: 5000 beam: (103, 50, 'right') direction: right len beam 47
# step: 6000 beam: (33, 5, 'down') direction: down len beam 56
# step: 7000 beam: (77, 59, 'up') direction: up len beam 53
# step: 8000 beam: (60, 40, 'down') direction: down len beam 54
# step: 9000 beam: (48, 94, 'right') direction: right len beam 45
# step: 10000 beam: (71, 97, 'down') direction: down len beam 29
# step: 11000 beam: (20, 21, 'left') direction: left len beam 18
# calculating edge:  1 (0, 1, 'down') done, energized= 7874
# calculating edge:  2 (0, 2, 'down')
# step: 1000 beam: (24, 27, 'left') direction: left len beam 13
# step: 2000 beam: (24, 100, 'up') direction: up len beam 17
# step: 3000 beam: (58, 55, 'down') direction: down len beam 31
# step: 4000 beam: (30, 56, 'down') direction: down len beam 46
# step: 5000 beam: (20, 51, 'up') direction: up len beam 50
# step: 6000 beam: (10, 97, 'down') direction: down len beam 60
# step: 7000 beam: (80, 98, 'down') direction: down len beam 55
# step: 8000 beam: (53, 74, 'up') direction: up len beam 50
# step: 9000 beam: (80, 51, 'up') direction: up len beam 42
# step: 10000 beam: (80, 54, 'left') direction: left len beam 29
# step: 11000 beam: (61, 16, 'down') direction: down len beam 7
# calculating edge:  2 (0, 2, 'down') done, energized= 7886
# calculating edge:  3 (0, 3, 'down')
# step: 1000 beam: (81, 14, 'down') direction: down len beam 12
# step: 2000 beam: (65, 37, 'right') direction: right len beam 31
# step: 3000 beam: (97, 42, 'right') direction: right len beam 35
# step: 4000 beam: (98, 78, 'left') direction: left len beam 39
# step: 5000 beam: (48, 42, 'left') direction: left len beam 40
# step: 6000 beam: (9, 19, 'right') direction: right len beam 36
# step: 7000 beam: (76, 40, 'down') direction: down len beam 44
# step: 8000 beam: (23, 72, 'left') direction: left len beam 34
# step: 9000 beam: (62, 100, 'right') direction: right len beam 37
# step: 10000 beam: (69, 78, 'right') direction: right len beam 29
# step: 11000 beam: (72, 63, 'up') direction: up len beam 17
# calculating edge:  3 (0, 3, 'down') done, energized= 7950
# calculating edge:  4 (0, 4, 'down')
# calculating edge:  4 (0, 4, 'down') done, energized= 31
# calculating edge:  5 (0, 5, 'down')
# step: 1000 beam: (20, 42, 'down') direction: down len beam 11
# step: 2000 beam: (76, 32, 'up') direction: up len beam 18
# step: 3000 beam: (50, 36, 'left') direction: left len beam 29
# step: 4000 beam: (54, 29, 'left') direction: left len beam 47
# step: 5000 beam: (43, 66, 'left') direction: left len beam 58
# step: 6000 beam: (4, 84, 'left') direction: left len beam 62
# step: 7000 beam: (84, 108, 'up') direction: up len beam 60
# step: 8000 beam: (52, 101, 'down') direction: down len beam 60
# step: 9000 beam: (11, 25, 'right') direction: right len beam 53
# step: 10000 beam: (93, 70, 'up') direction: up len beam 36
# step: 11000 beam: (83, 93, 'right') direction: right len beam 6
# calculating edge:  5 (0, 5, 'down') done, energized= 7859
# calculating edge:  6 (0, 6, 'down')
# step: 1000 beam: (61, 45, 'down') direction: down len beam 15
# step: 2000 beam: (62, 107, 'left') direction: left len beam 32
# step: 3000 beam: (72, 71, 'right') direction: right len beam 37
# step: 4000 beam: (63, 51, 'left') direction: left len beam 47
# step: 5000 beam: (97, 47, 'right') direction: right len beam 51
# step: 6000 beam: (22, 100, 'up') direction: up len beam 47
# step: 7000 beam: (40, 69, 'down') direction: down len beam 45
# step: 8000 beam: (2, 95, 'left') direction: left len beam 49
# step: 9000 beam: (68, 17, 'right') direction: right len beam 37
# step: 10000 beam: (22, 30, 'up') direction: up len beam 33
# step: 11000 beam: (62, 65, 'up') direction: up len beam 21
# calculating edge:  6 (0, 6, 'down') done, energized= 7855
# calculating edge:  7 (0, 7, 'down')
# calculating edge:  7 (0, 7, 'down') done, energized= 18
# calculating edge:  8 (0, 8, 'down')
# calculating edge:  8 (0, 8, 'down') done, energized= 110
# calculating edge:  9 (0, 9, 'down')
# step: 1000 beam: (79, 20, 'right') direction: right len beam 12
# step: 2000 beam: (53, 41, 'up') direction: up len beam 31
# step: 3000 beam: (88, 85, 'up') direction: up len beam 35
# step: 4000 beam: (100, 72, 'left') direction: left len beam 39
# step: 5000 beam: (66, 56, 'up') direction: up len beam 40
# step: 6000 beam: (21, 41, 'right') direction: right len beam 36
# step: 7000 beam: (58, 54, 'up') direction: up len beam 44
# step: 8000 beam: (37, 88, 'right') direction: right len beam 34
# step: 9000 beam: (38, 46, 'left') direction: left len beam 37
# step: 10000 beam: (78, 107, 'right') direction: right len beam 29
# step: 11000 beam: (81, 68, 'right') direction: right len beam 17
# calculating edge:  9 (0, 9, 'down') done, energized= 7950
# calculating edge:  10 (0, 10, 'down')
# step: 1000 beam: (60, 53, 'down') direction: down len beam 15
# step: 2000 beam: (82, 41, 'down') direction: down len beam 21
# step: 3000 beam: (91, 41, 'right') direction: right len beam 21
# step: 4000 beam: (57, 92, 'right') direction: right len beam 25
# step: 5000 beam: (50, 64, 'left') direction: left len beam 33
# step: 6000 beam: (101, 70, 'down') direction: down len beam 40
# step: 7000 beam: (73, 63, 'up') direction: up len beam 52
# step: 8000 beam: (79, 96, 'left') direction: left len beam 53
# step: 9000 beam: (47, 76, 'down') direction: down len beam 45
# step: 10000 beam: (108, 74, 'left') direction: left len beam 36
# step: 11000 beam: (49, 104, 'down') direction: down len beam 16
# calculating edge:  10 (0, 10, 'down') done, energized= 7931
# calculating edge:  11 (0, 11, 'down')
# calculating edge:  11 (0, 11, 'down') done, energized= 18
# calculating edge:  12 (0, 12, 'down')
# calculating edge:  12 (0, 12, 'down') done, energized= 22
# calculating edge:  13 (0, 13, 'down')
# step: 1000 beam: (64, 53, 'down') direction: down len beam 11
# step: 2000 beam: (52, 29, 'left') direction: left len beam 17
# step: 3000 beam: (15, 24, 'up') direction: up len beam 28
# step: 4000 beam: (41, 106, 'up') direction: up len beam 47
# step: 5000 beam: (18, 49, 'left') direction: left len beam 58
# step: 6000 beam: (50, 86, 'up') direction: up len beam 62
# step: 7000 beam: (41, 34, 'up') direction: up len beam 60
# step: 8000 beam: (6, 85, 'left') direction: left len beam 61
# step: 9000 beam: (34, 50, 'right') direction: right len beam 52
# step: 10000 beam: (106, 109, 'down') direction: down len beam 36
# step: 11000 beam: (87, 92, 'up') direction: up len beam 6
# calculating edge:  13 (0, 13, 'down') done, energized= 7862
# calculating edge:  14 (0, 14, 'down')
# step: 1000 beam: (5, 45, 'right') direction: right len beam 7
# step: 2000 beam: (76, 31, 'down') direction: down len beam 16
# step: 3000 beam: (92, 36, 'up') direction: up len beam 28
# step: 4000 beam: (40, 67, 'right') direction: right len beam 38
# step: 5000 beam: (107, 73, 'right') direction: right len beam 51
# step: 6000 beam: (87, 70, 'right') direction: right len beam 54
# step: 7000 beam: (99, 43, 'up') direction: up len beam 60
# step: 8000 beam: (52, 83, 'up') direction: up len beam 56
# step: 9000 beam: (74, 73, 'down') direction: down len beam 47
# step: 10000 beam: (83, 51, 'up') direction: up len beam 33
# step: 11000 beam: (90, 92, 'down') direction: down len beam 6
# calculating edge:  14 (0, 14, 'down') done, energized= 7862
# calculating edge:  15 (0, 15, 'down')
# step: 1000 beam: (78, 28, 'down') direction: down len beam 13
# step: 2000 beam: (77, 9, 'right') direction: right len beam 17
# step: 3000 beam: (90, 84, 'right') direction: right len beam 30
# step: 4000 beam: (20, 77, 'up') direction: up len beam 48
# step: 5000 beam: (42, 92, 'down') direction: down len beam 49
# step: 6000 beam: (23, 73, 'left') direction: left len beam 58
# step: 7000 beam: (6, 97, 'right') direction: right len beam 55
# step: 8000 beam: (47, 63, 'up') direction: up len beam 48
# step: 9000 beam: (92, 102, 'down') direction: down len beam 42
# step: 10000 beam: (20, 92, 'up') direction: up len beam 29
# step: 11000 beam: (83, 88, 'right') direction: right len beam 5
# calculating edge:  15 (0, 15, 'down') done, energized= 7856
# calculating edge:  16 (0, 16, 'down')
# step: 1000 beam: (1, 12, 'left') direction: left len beam 12
# step: 2000 beam: (32, 55, 'down') direction: down len beam 19
# step: 3000 beam: (53, 41, 'right') direction: right len beam 24
# step: 4000 beam: (74, 6, 'down') direction: down len beam 34
# step: 5000 beam: (74, 43, 'down') direction: down len beam 42
# step: 6000 beam: (55, 25, 'left') direction: left len beam 52
# step: 7000 beam: (48, 12, 'left') direction: left len beam 50
# step: 8000 beam: (43, 108, 'right') direction: right len beam 53
# step: 9000 beam: (19, 90, 'up') direction: up len beam 46
# step: 10000 beam: (64, 86, 'right') direction: right len beam 29
# step: 11000 beam: (50, 76, 'right') direction: right len beam 18
# calculating edge:  16 (0, 16, 'down') done, energized= 7901
# calculating edge:  17 (0, 17, 'down')
# calculating edge:  17 (0, 17, 'down') done, energized= 41
# calculating edge:  18 (0, 18, 'down')
# calculating edge:  18 (0, 18, 'down') done, energized= 44
# calculating edge:  19 (0, 19, 'down')
# step: 1000 beam: (50, 4, 'left') direction: left len beam 11
# step: 2000 beam: (35, 60, 'up') direction: up len beam 17
# step: 3000 beam: (29, 64, 'down') direction: down len beam 28
# step: 4000 beam: (47, 3, 'left') direction: left len beam 47
# step: 5000 beam: (50, 97, 'up') direction: up len beam 58
# step: 6000 beam: (40, 110, 'right') direction: right len beam 63
# step: 7000 beam: (43, 108, 'right') direction: right len beam 60
# step: 8000 beam: (63, 38, 'right') direction: right len beam 62
# step: 9000 beam: (3, 77, 'right') direction: right len beam 52
# step: 10000 beam: (64, 104, 'right') direction: right len beam 36
# step: 11000 beam: (15, 110, 'right') direction: right len beam 8
# calculating edge:  19 (0, 19, 'down') done, energized= 7870
# calculating edge:  20 (0, 20, 'down')
# step: 1000 beam: (16, 52, 'up') direction: up len beam 13
# step: 2000 beam: (40, 46, 'right') direction: right len beam 17
# step: 3000 beam: (57, 25, 'up') direction: up len beam 30
# step: 4000 beam: (56, 56, 'up') direction: up len beam 48
# step: 5000 beam: (37, 69, 'right') direction: right len beam 48
# step: 6000 beam: (26, 64, 'up') direction: up len beam 58
# step: 7000 beam: (26, 65, 'left') direction: left len beam 55
# step: 8000 beam: (90, 68, 'right') direction: right len beam 48
# step: 9000 beam: (19, 22, 'right') direction: right len beam 42
# step: 10000 beam: (104, 7, 'left') direction: left len beam 29
# step: 11000 beam: (38, 61, 'left') direction: left len beam 5
# calculating edge:  20 (0, 20, 'down') done, energized= 7856
# calculating edge:  21 (0, 21, 'down')
# step: 1000 beam: (67, 66, 'left') direction: left len beam 11
# step: 2000 beam: (91, 43, 'right') direction: right len beam 18
# step: 3000 beam: (30, 64, 'down') direction: down len beam 30
# step: 4000 beam: (12, 87, 'left') direction: left len beam 48
# step: 5000 beam: (54, 23, 'left') direction: left len beam 58
# step: 6000 beam: (43, 93, 'right') direction: right len beam 61
# step: 7000 beam: (96, 46, 'left') direction: left len beam 60
# step: 8000 beam: (60, 35, 'left') direction: left len beam 61
# step: 9000 beam: (80, 59, 'left') direction: left len beam 53
# step: 10000 beam: (46, 27, 'left') direction: left len beam 36
# step: 11000 beam: (109, 77, 'down') direction: down len beam 6
# calculating edge:  21 (0, 21, 'down') done, energized= 7855
# calculating edge:  22 (0, 22, 'down')
# step: 1000 beam: (79, 20, 'right') direction: right len beam 12
# step: 2000 beam: (53, 41, 'up') direction: up len beam 31
# step: 3000 beam: (88, 85, 'up') direction: up len beam 35
# step: 4000 beam: (100, 72, 'left') direction: left len beam 39
# step: 5000 beam: (66, 56, 'up') direction: up len beam 40
# step: 6000 beam: (21, 41, 'right') direction: right len beam 36
# step: 7000 beam: (58, 54, 'up') direction: up len beam 44
# step: 8000 beam: (37, 88, 'right') direction: right len beam 34
# step: 9000 beam: (38, 46, 'left') direction: left len beam 37
# step: 10000 beam: (78, 107, 'right') direction: right len beam 29
# step: 11000 beam: (81, 68, 'right') direction: right len beam 17
# calculating edge:  22 (0, 22, 'down') done, energized= 7950
# calculating edge:  23 (0, 23, 'down')
# step: 1000 beam: (37, 1, 'left') direction: left len beam 12
# step: 2000 beam: (51, 47, 'right') direction: right len beam 17
# step: 3000 beam: (14, 90, 'down') direction: down len beam 30
# step: 4000 beam: (31, 75, 'left') direction: left len beam 44
# step: 5000 beam: (52, 19, 'right') direction: right len beam 50
# step: 6000 beam: (55, 99, 'up') direction: up len beam 61
# step: 7000 beam: (74, 64, 'down') direction: down len beam 52
# step: 8000 beam: (30, 31, 'left') direction: left len beam 49
# step: 9000 beam: (108, 101, 'down') direction: down len beam 42
# step: 10000 beam: (57, 68, 'left') direction: left len beam 29
# step: 11000 beam: (83, 84, 'right') direction: right len beam 7
# calculating edge:  23 (0, 23, 'down') done, energized= 7866
# calculating edge:  24 (0, 24, 'down')
# step: 1000 beam: (52, 55, 'down') direction: down len beam 11
# step: 2000 beam: (74, 53, 'right') direction: right len beam 17
# step: 3000 beam: (53, 10, 'down') direction: down len beam 30
# step: 4000 beam: (54, 7, 'left') direction: left len beam 44
# step: 5000 beam: (103, 70, 'down') direction: down len beam 50
# step: 6000 beam: (40, 90, 'down') direction: down len beam 61
# step: 7000 beam: (87, 44, 'up') direction: up len beam 52
# step: 8000 beam: (43, 66, 'down') direction: down len beam 49
# step: 9000 beam: (59, 92, 'right') direction: right len beam 42
# step: 10000 beam: (104, 46, 'down') direction: down len beam 29
# step: 11000 beam: (62, 40, 'up') direction: up len beam 7
# calculating edge:  24 (0, 24, 'down') done, energized= 7872
# calculating edge:  25 (0, 25, 'down')
# step: 1000 beam: (46, 19, 'down') direction: down len beam 9
# step: 2000 beam: (11, 25, 'up') direction: up len beam 17
# step: 3000 beam: (79, 86, 'up') direction: up len beam 29
# step: 4000 beam: (67, 69, 'up') direction: up len beam 37
# step: 5000 beam: (79, 32, 'up') direction: up len beam 44
# step: 6000 beam: (96, 40, 'up') direction: up len beam 56
# step: 7000 beam: (56, 52, 'down') direction: down len beam 50
# step: 8000 beam: (67, 110, 'right') direction: right len beam 53
# step: 9000 beam: (34, 103, 'up') direction: up len beam 43
# step: 10000 beam: (92, 92, 'down') direction: down len beam 28
# step: 11000 beam: (44, 91, 'right') direction: right len beam 18
# calculating edge:  25 (0, 25, 'down') done, energized= 7855
# calculating edge:  26 (0, 26, 'down')
# step: 1000 beam: (29, 36, 'right') direction: right len beam 6
# step: 2000 beam: (45, -1, 'left') direction: left len beam 19
# step: 3000 beam: (77, 6, 'down') direction: down len beam 29
# step: 4000 beam: (18, 78, 'right') direction: right len beam 38
# step: 5000 beam: (56, 10, 'down') direction: down len beam 55
# step: 6000 beam: (86, 49, 'left') direction: left len beam 56
# step: 7000 beam: (83, 2, 'down') direction: down len beam 59
# step: 8000 beam: (70, 90, 'down') direction: down len beam 56
# step: 9000 beam: (62, 35, 'up') direction: up len beam 47
# step: 10000 beam: (37, 107, 'right') direction: right len beam 35
# step: 11000 beam: (109, 77, 'down') direction: down len beam 6
# calculating edge:  26 (0, 26, 'down') done, energized= 7858
# calculating edge:  27 (0, 27, 'down')
# calculating edge:  27 (0, 27, 'down') done, energized= 56
# calculating edge:  28 (0, 28, 'down')
# step: 1000 beam: (34, 50, 'right') direction: right len beam 15
# step: 2000 beam: (96, 40, 'down') direction: down len beam 23
# step: 3000 beam: (29, 40, 'right') direction: right len beam 26
# step: 4000 beam: (55, 11, 'left') direction: left len beam 35
# step: 5000 beam: (93, 93, 'down') direction: down len beam 37
# step: 6000 beam: (74, 35, 'up') direction: up len beam 39
# step: 7000 beam: (30, 73, 'up') direction: up len beam 36
# step: 8000 beam: (87, 62, 'down') direction: down len beam 29
# step: 9000 beam: (35, 74, 'down') direction: down len beam 26
# step: 10000 beam: (4, 107, 'up') direction: up len beam 24
# step: 11000 beam: (6, 98, 'right') direction: right len beam 15
# calculating edge:  28 (0, 28, 'down') done, energized= 7905
# calculating edge:  29 (0, 29, 'down')
# step: 1000 beam: (1, 27, 'right') direction: right len beam 11
# step: 2000 beam: (92, 102, 'right') direction: right len beam 19
# step: 3000 beam: (28, 49, 'down') direction: down len beam 32
# step: 4000 beam: (60, 27, 'left') direction: left len beam 38
# step: 5000 beam: (92, 45, 'right') direction: right len beam 45
# step: 6000 beam: (62, 74, 'left') direction: left len beam 56
# step: 7000 beam: (43, 91, 'right') direction: right len beam 50
# step: 8000 beam: (74, 10, 'down') direction: down len beam 53
# step: 9000 beam: (27, 62, 'left') direction: left len beam 43
# step: 10000 beam: (14, 21, 'up') direction: up len beam 28
# step: 11000 beam: (35, 79, 'up') direction: up len beam 16
# calculating edge:  29 (0, 29, 'down') done, energized= 7855
# calculating edge:  30 (0, 30, 'down')
# step: 1000 beam: (47, 3, 'up') direction: up len beam 10
# step: 2000 beam: (70, 33, 'up') direction: up len beam 17
# step: 3000 beam: (23, 75, 'left') direction: left len beam 23
# step: 4000 beam: (67, 45, 'down') direction: down len beam 44
# step: 5000 beam: (40, 94, 'down') direction: down len beam 53
# step: 6000 beam: (104, 48, 'right') direction: right len beam 55
# step: 7000 beam: (62, 84, 'right') direction: right len beam 52
# step: 8000 beam: (79, 33, 'left') direction: left len beam 47
# step: 9000 beam: (103, 106, 'down') direction: down len beam 43
# step: 10000 beam: (100, 89, 'left') direction: left len beam 28
# step: 11000 beam: (21, 98, 'up') direction: up len beam 5
# calculating edge:  30 (0, 30, 'down') done, energized= 7856
# calculating edge:  31 (0, 31, 'down')
# step: 1000 beam: (30, 6, 'up') direction: up len beam 16
# step: 2000 beam: (56, 30, 'up') direction: up len beam 19
# step: 3000 beam: (103, 70, 'down') direction: down len beam 26
# step: 4000 beam: (81, 73, 'up') direction: up len beam 36
# step: 5000 beam: (65, 43, 'down') direction: down len beam 38
# step: 6000 beam: (26, -1, 'left') direction: left len beam 40
# step: 7000 beam: (106, 46, 'down') direction: down len beam 36
# step: 8000 beam: (15, 65, 'down') direction: down len beam 33
# step: 9000 beam: (100, 81, 'left') direction: left len beam 27
# step: 10000 beam: (49, 101, 'down') direction: down len beam 27
# step: 11000 beam: (64, 104, 'down') direction: down len beam 15
# calculating edge:  31 (0, 31, 'down') done, energized= 7912
# calculating edge:  32 (0, 32, 'down')
# calculating edge:  32 (0, 32, 'down') done, energized= 44
# calculating edge:  33 (0, 33, 'down')
# step: 1000 beam: (49, 3, 'up') direction: up len beam 8
# step: 2000 beam: (40, 93, 'left') direction: left len beam 19
# step: 3000 beam: (34, 14, 'left') direction: left len beam 22
# step: 4000 beam: (87, 36, 'up') direction: up len beam 44
# step: 5000 beam: (72, 66, 'left') direction: left len beam 52
# step: 6000 beam: (66, 92, 'down') direction: down len beam 52
# step: 7000 beam: (105, 65, 'down') direction: down len beam 51
# step: 8000 beam: (48, 84, 'left') direction: left len beam 47
# step: 9000 beam: (84, 97, 'left') direction: left len beam 43
# step: 10000 beam: (14, 73, 'right') direction: right len beam 28
# step: 11000 beam: (67, 16, 'down') direction: down len beam 5
# calculating edge:  33 (0, 33, 'down') done, energized= 7860
# calculating edge:  34 (0, 34, 'down')
# calculating edge:  34 (0, 34, 'down') done, energized= 23
# calculating edge:  35 (0, 35, 'down')
# calculating edge:  35 (0, 35, 'down') done, energized= 44
# calculating edge:  36 (0, 36, 'down')
# step: 1000 beam: (51, 28, 'down') direction: down len beam 10
# step: 2000 beam: (37, 60, 'up') direction: up len beam 17
# step: 3000 beam: (76, 36, 'up') direction: up len beam 28
# step: 4000 beam: (60, 108, 'down') direction: down len beam 47
# step: 5000 beam: (97, 47, 'right') direction: right len beam 57
# step: 6000 beam: (43, 92, 'right') direction: right len beam 64
# step: 7000 beam: (99, 30, 'left') direction: left len beam 59
# step: 8000 beam: (98, 7, 'left') direction: left len beam 61
# step: 9000 beam: (5, 69, 'up') direction: up len beam 52
# step: 10000 beam: (83, 39, 'down') direction: down len beam 36
# step: 11000 beam: (33, 86, 'left') direction: left len beam 7
# calculating edge:  36 (0, 36, 'down') done, energized= 7870
# calculating edge:  37 (0, 37, 'down')
# calculating edge:  37 (0, 37, 'down') done, energized= 56
# calculating edge:  38 (0, 38, 'down')
# step: 1000 beam: (50, 40, 'left') direction: left len beam 16
# step: 2000 beam: (35, 20, 'up') direction: up len beam 42
# step: 3000 beam: (80, 37, 'up') direction: up len beam 46
# step: 4000 beam: (79, 26, 'left') direction: left len beam 47
# step: 5000 beam: (54, 28, 'right') direction: right len beam 44
# step: 6000 beam: (5, 52, 'up') direction: up len beam 44
# step: 7000 beam: (63, 10, 'right') direction: right len beam 37
# step: 8000 beam: (23, 64, 'up') direction: up len beam 35
# step: 9000 beam: (33, 65, 'up') direction: up len beam 36
# step: 10000 beam: (27, 67, 'left') direction: left len beam 24
# step: 11000 beam: (93, 85, 'up') direction: up len beam 16
# calculating edge:  38 (0, 38, 'down') done, energized= 7885
# calculating edge:  39 (0, 39, 'down')
# step: 1000 beam: (40, 56, 'left') direction: left len beam 15
# step: 2000 beam: (18, 85, 'left') direction: left len beam 39
# step: 3000 beam: (64, 43, 'down') direction: down len beam 41
# step: 4000 beam: (73, 41, 'down') direction: down len beam 41
# step: 5000 beam: (1, 7, 'left') direction: left len beam 47
# step: 6000 beam: (79, 81, 'up') direction: up len beam 43
# step: 7000 beam: (85, 41, 'left') direction: left len beam 43
# step: 8000 beam: (108, 106, 'down') direction: down len beam 37
# step: 9000 beam: (66, 94, 'left') direction: left len beam 37
# step: 10000 beam: (97, 96, 'left') direction: left len beam 29
# step: 11000 beam: (13, 29, 'down') direction: down len beam 21
# calculating edge:  39 (0, 39, 'down') done, energized= 8013
# calculating edge:  40 (0, 40, 'down')
# calculating edge:  40 (0, 40, 'down') done, energized= 88
# calculating edge:  41 (0, 41, 'down')
# calculating edge:  41 (0, 41, 'down') done, energized= 24
# calculating edge:  42 (0, 42, 'down')
# calculating edge:  42 (0, 42, 'down') done, energized= 66
# calculating edge:  43 (0, 43, 'down')
# step: 1000 beam: (61, 37, 'up') direction: up len beam 19
# step: 2000 beam: (66, 90, 'down') direction: down len beam 30
# step: 3000 beam: (70, 45, 'down') direction: down len beam 35
# step: 4000 beam: (81, 2, 'down') direction: down len beam 46
# step: 5000 beam: (96, 71, 'left') direction: left len beam 43
# step: 6000 beam: (13, 107, 'down') direction: down len beam 45
# step: 7000 beam: (53, 29, 'left') direction: left len beam 49
# step: 8000 beam: (4, 64, 'left') direction: left len beam 42
# step: 9000 beam: (46, 27, 'up') direction: up len beam 31
# step: 10000 beam: (44, 108, 'right') direction: right len beam 27
# step: 11000 beam: (81, 68, 'right') direction: right len beam 20
# calculating edge:  43 (0, 43, 'down') done, energized= 7936
# calculating edge:  44 (0, 44, 'down')
# step: 1000 beam: (96, 44, 'right') direction: right len beam 16
# step: 2000 beam: (2, 31, 'left') direction: left len beam 31
# step: 3000 beam: (81, 82, 'up') direction: up len beam 40
# step: 4000 beam: (24, 20, 'left') direction: left len beam 49
# step: 5000 beam: (83, 63, 'up') direction: up len beam 46
# step: 6000 beam: (34, 24, 'left') direction: left len beam 50
# step: 7000 beam: (85, 31, 'left') direction: left len beam 35
# step: 8000 beam: (33, 94, 'right') direction: right len beam 33
# step: 9000 beam: (37, 65, 'up') direction: up len beam 34
# step: 10000 beam: (14, 40, 'up') direction: up len beam 22
# step: 11000 beam: (53, 67, 'up') direction: up len beam 16
# calculating edge:  44 (0, 44, 'down') done, energized= 7875
# calculating edge:  45 (0, 45, 'down')
# step: 1000 beam: (79, 20, 'right') direction: right len beam 12
# step: 2000 beam: (53, 41, 'up') direction: up len beam 31
# step: 3000 beam: (88, 85, 'up') direction: up len beam 35
# step: 4000 beam: (100, 72, 'left') direction: left len beam 39
# step: 5000 beam: (66, 56, 'up') direction: up len beam 40
# step: 6000 beam: (21, 41, 'right') direction: right len beam 36
# step: 7000 beam: (58, 54, 'up') direction: up len beam 44
# step: 8000 beam: (37, 88, 'right') direction: right len beam 34
# step: 9000 beam: (38, 46, 'left') direction: left len beam 37
# step: 10000 beam: (78, 107, 'right') direction: right len beam 29
# step: 11000 beam: (81, 68, 'right') direction: right len beam 17
# calculating edge:  45 (0, 45, 'down') done, energized= 7950
# calculating edge:  46 (0, 46, 'down')
# step: 1000 beam: (73, 79, 'up') direction: up len beam 17
# step: 2000 beam: (66, 90, 'right') direction: right len beam 29
# step: 3000 beam: (19, 95, 'left') direction: left len beam 40
# step: 4000 beam: (80, 36, 'up') direction: up len beam 39
# step: 5000 beam: (58, 95, 'left') direction: left len beam 52
# step: 6000 beam: (34, 49, 'down') direction: down len beam 58
# step: 7000 beam: (69, 16, 'left') direction: left len beam 55
# step: 8000 beam: (18, 79, 'left') direction: left len beam 50
# step: 9000 beam: (6, 98, 'right') direction: right len beam 50
# step: 10000 beam: (108, 53, 'down') direction: down len beam 32
# step: 11000 beam: (64, 95, 'right') direction: right len beam 20
# calculating edge:  46 (0, 46, 'down') done, energized= 7962
# calculating edge:  47 (0, 47, 'down')
# step: 1000 beam: (31, 91, 'right') direction: right len beam 16
# step: 2000 beam: (37, 1, 'left') direction: left len beam 41
# step: 3000 beam: (8, 65, 'up') direction: up len beam 42
# step: 4000 beam: (13, 37, 'up') direction: up len beam 42
# step: 5000 beam: (59, 97, 'right') direction: right len beam 47
# step: 6000 beam: (11, 36, 'right') direction: right len beam 42
# step: 7000 beam: (96, 56, 'right') direction: right len beam 43
# step: 8000 beam: (79, 103, 'down') direction: down len beam 39
# step: 9000 beam: (38, 52, 'left') direction: left len beam 36
# step: 10000 beam: (61, 24, 'down') direction: down len beam 29
# step: 11000 beam: (102, 62, 'up') direction: up len beam 18
# calculating edge:  47 (0, 47, 'down') done, energized= 7966
# calculating edge:  48 (0, 48, 'down')
# step: 1000 beam: (66, 74, 'right') direction: right len beam 17
# step: 2000 beam: (63, 99, 'right') direction: right len beam 20
# step: 3000 beam: (21, 68, 'up') direction: up len beam 29
# step: 4000 beam: (33, 96, 'right') direction: right len beam 46
# step: 5000 beam: (4, 80, 'left') direction: left len beam 54
# step: 6000 beam: (91, 39, 'right') direction: right len beam 60
# step: 7000 beam: (40, 57, 'right') direction: right len beam 57
# step: 8000 beam: (1, 11, 'left') direction: left len beam 51
# step: 9000 beam: (63, 5, 'down') direction: down len beam 34
# step: 10000 beam: (71, 13, 'left') direction: left len beam 24
# step: 11000 beam: (10, 7, 'left') direction: left len beam 13
# calculating edge:  48 (0, 48, 'down') done, energized= 7886
# calculating edge:  49 (0, 49, 'down')
# calculating edge:  49 (0, 49, 'down') done, energized= 53
# calculating edge:  50 (0, 50, 'down')
# step: 1000 beam: (5, 18, 'right') direction: right len beam 10
# step: 2000 beam: (53, 45, 'up') direction: up len beam 18
# step: 3000 beam: (75, 76, 'left') direction: left len beam 29
# step: 4000 beam: (82, 74, 'down') direction: down len beam 37
# step: 5000 beam: (19, 82, 'left') direction: left len beam 44
# step: 6000 beam: (95, 83, 'left') direction: left len beam 55
# step: 7000 beam: (48, 10, 'left') direction: left len beam 50
# step: 8000 beam: (37, 104, 'left') direction: left len beam 52
# step: 9000 beam: (17, 52, 'down') direction: down len beam 43
# step: 10000 beam: (52, 86, 'up') direction: up len beam 28
# step: 11000 beam: (44, 59, 'up') direction: up len beam 18
# calculating edge:  50 (0, 50, 'down') done, energized= 7858
# calculating edge:  51 (0, 51, 'down')
# step: 1000 beam: (50, 9, 'left') direction: left len beam 5
# step: 2000 beam: (23, 13, 'right') direction: right len beam 15
# step: 3000 beam: (69, 21, 'left') direction: left len beam 22
# step: 4000 beam: (23, 66, 'left') direction: left len beam 42
# step: 5000 beam: (48, 10, 'left') direction: left len beam 53
# step: 6000 beam: (76, 52, 'down') direction: down len beam 51
# step: 7000 beam: (30, 65, 'up') direction: up len beam 51
# step: 8000 beam: (6, 73, 'left') direction: left len beam 46
# step: 9000 beam: (94, 96, 'down') direction: down len beam 43
# step: 10000 beam: (50, 90, 'right') direction: right len beam 32
# step: 11000 beam: (62, 16, 'down') direction: down len beam 7
# calculating edge:  51 (0, 51, 'down') done, energized= 7879
# calculating edge:  52 (0, 52, 'down')
# step: 1000 beam: (36, 29, 'down') direction: down len beam 11
# step: 2000 beam: (28, 16, 'right') direction: right len beam 21
# step: 3000 beam: (11, 27, 'right') direction: right len beam 25
# step: 4000 beam: (62, 41, 'up') direction: up len beam 21
# step: 5000 beam: (66, 55, 'down') direction: down len beam 27
# step: 6000 beam: (36, 66, 'left') direction: left len beam 40
# step: 7000 beam: (18, 81, 'left') direction: left len beam 48
# step: 8000 beam: (74, 97, 'down') direction: down len beam 42
# step: 9000 beam: (85, 95, 'left') direction: left len beam 35
# step: 10000 beam: (92, 87, 'down') direction: down len beam 33
# step: 11000 beam: (50, 92, 'right') direction: right len beam 17
# calculating edge:  52 (0, 52, 'down') done, energized= 7877
# calculating edge:  53 (0, 53, 'down')
# step: 1000 beam: (67, 73, 'up') direction: up len beam 10
# step: 2000 beam: (80, 32, 'up') direction: up len beam 17
# step: 3000 beam: (60, 49, 'down') direction: down len beam 28
# step: 4000 beam: (39, 68, 'left') direction: left len beam 46
# step: 5000 beam: (35, 95, 'down') direction: down len beam 57
# step: 6000 beam: (0, 85, 'up') direction: up len beam 63
# step: 7000 beam: (99, 30, 'left') direction: left len beam 59
# step: 8000 beam: (98, 7, 'left') direction: left len beam 61
# step: 9000 beam: (5, 69, 'up') direction: up len beam 52
# step: 10000 beam: (83, 39, 'down') direction: down len beam 36
# step: 11000 beam: (33, 86, 'left') direction: left len beam 7
# calculating edge:  53 (0, 53, 'down') done, energized= 7870
# calculating edge:  54 (0, 54, 'down')
# calculating edge:  54 (0, 54, 'down') done, energized= 23
# calculating edge:  55 (0, 55, 'down')
# calculating edge:  55 (0, 55, 'down') done, energized= 46
# calculating edge:  56 (0, 56, 'down')
# step: 1000 beam: (1, 20, 'right') direction: right len beam 10
# step: 2000 beam: (72, 55, 'down') direction: down len beam 18
# step: 3000 beam: (93, 95, 'right') direction: right len beam 30
# step: 4000 beam: (54, 12, 'down') direction: down len beam 38
# step: 5000 beam: (98, 18, 'left') direction: left len beam 44
# step: 6000 beam: (21, 75, 'up') direction: up len beam 55
# step: 7000 beam: (66, 26, 'left') direction: left len beam 51
# step: 8000 beam: (32, 67, 'down') direction: down len beam 52
# step: 9000 beam: (89, 69, 'down') direction: down len beam 43
# step: 10000 beam: (63, 64, 'right') direction: right len beam 27
# step: 11000 beam: (38, 67, 'left') direction: left len beam 17
# calculating edge:  56 (0, 56, 'down') done, energized= 7855
# calculating edge:  57 (0, 57, 'down')
# calculating edge:  57 (0, 57, 'down') done, energized= 102
# calculating edge:  58 (0, 58, 'down')
# step: 1000 beam: (13, 6, 'up') direction: up len beam 8
# step: 2000 beam: (57, 45, 'up') direction: up len beam 18
# step: 3000 beam: (76, 78, 'left') direction: left len beam 26
# step: 4000 beam: (40, 103, 'up') direction: up len beam 37
# step: 5000 beam: (90, 33, 'right') direction: right len beam 42
# step: 6000 beam: (103, 5, 'down') direction: down len beam 52
# step: 7000 beam: (95, 67, 'left') direction: left len beam 50
# step: 8000 beam: (80, 101, 'right') direction: right len beam 54
# step: 9000 beam: (15, 64, 'left') direction: left len beam 46
# step: 10000 beam: (14, 85, 'right') direction: right len beam 28
# step: 11000 beam: (44, 89, 'right') direction: right len beam 16
# calculating edge:  58 (0, 58, 'down') done, energized= 7864
# calculating edge:  59 (0, 59, 'down')
# step: 1000 beam: (42, 30, 'down') direction: down len beam 18
# step: 2000 beam: (44, 76, 'down') direction: down len beam 23
# step: 3000 beam: (38, 36, 'down') direction: down len beam 38
# step: 4000 beam: (24, 89, 'right') direction: right len beam 48
# step: 5000 beam: (36, 24, 'up') direction: up len beam 49
# step: 6000 beam: (94, 35, 'down') direction: down len beam 56
# step: 7000 beam: (19, 24, 'right') direction: right len beam 51
# step: 8000 beam: (1, 98, 'right') direction: right len beam 42
# step: 9000 beam: (102, 53, 'down') direction: down len beam 35
# step: 10000 beam: (105, 62, 'left') direction: left len beam 25
# step: 11000 beam: (61, 22, 'down') direction: down len beam 14
# calculating edge:  59 (0, 59, 'down') done, energized= 7855
# calculating edge:  60 (0, 60, 'down')
# step: 1000 beam: (15, 78, 'right') direction: right len beam 16
# step: 2000 beam: (22, 73, 'right') direction: right len beam 41
# step: 3000 beam: (37, 94, 'right') direction: right len beam 43
# step: 4000 beam: (54, 76, 'down') direction: down len beam 41
# step: 5000 beam: (74, 74, 'down') direction: down len beam 48
# step: 6000 beam: (60, 58, 'right') direction: right len beam 42
# step: 7000 beam: (36, 24, 'up') direction: up len beam 43
# step: 8000 beam: (96, 86, 'down') direction: down len beam 38
# step: 9000 beam: (81, 53, 'left') direction: left len beam 36
# step: 10000 beam: (77, 21, 'down') direction: down len beam 30
# step: 11000 beam: (17, 29, 'down') direction: down len beam 16
# calculating edge:  60 (0, 60, 'down') done, energized= 7958
# calculating edge:  61 (0, 61, 'down')
# step: 1000 beam: (31, 91, 'up') direction: up len beam 17
# step: 2000 beam: (72, 77, 'right') direction: right len beam 29
# step: 3000 beam: (58, 55, 'down') direction: down len beam 41
# step: 4000 beam: (14, 32, 'left') direction: left len beam 39
# step: 5000 beam: (43, 6, 'down') direction: down len beam 50
# step: 6000 beam: (34, 106, 'up') direction: up len beam 58
# step: 7000 beam: (40, 92, 'down') direction: down len beam 55
# step: 8000 beam: (74, 52, 'down') direction: down len beam 50
# step: 9000 beam: (90, 21, 'down') direction: down len beam 51
# step: 10000 beam: (102, 28, 'up') direction: up len beam 33
# step: 11000 beam: (31, 6, 'up') direction: up len beam 20
# calculating edge:  61 (0, 61, 'down') done, energized= 7984
# calculating edge:  62 (0, 62, 'down')
# step: 1000 beam: (32, 64, 'up') direction: up len beam 10
# step: 2000 beam: (98, 58, 'left') direction: left len beam 18
# step: 3000 beam: (93, 94, 'right') direction: right len beam 29
# step: 4000 beam: (89, 53, 'left') direction: left len beam 37
# step: 5000 beam: (69, 77, 'down') direction: down len beam 44
# step: 6000 beam: (105, 61, 'left') direction: left len beam 55
# step: 7000 beam: (34, 58, 'left') direction: left len beam 51
# step: 8000 beam: (47, 22, 'down') direction: down len beam 52
# step: 9000 beam: (15, 63, 'up') direction: up len beam 43
# step: 10000 beam: (37, 93, 'right') direction: right len beam 28
# step: 11000 beam: (75, 51, 'up') direction: up len beam 17
# calculating edge:  62 (0, 62, 'down') done, energized= 7855
# calculating edge:  63 (0, 63, 'down')
# step: 1000 beam: (29, 22, 'right') direction: right len beam 10
# step: 2000 beam: (56, 7, 'left') direction: left len beam 21
# step: 3000 beam: (90, -1, 'left') direction: left len beam 24
# step: 4000 beam: (79, 31, 'down') direction: down len beam 20
# step: 5000 beam: (34, 62, 'left') direction: left len beam 27
# step: 6000 beam: (27, 51, 'up') direction: up len beam 40
# step: 7000 beam: (66, 93, 'right') direction: right len beam 49
# step: 8000 beam: (87, 66, 'right') direction: right len beam 42
# step: 9000 beam: (79, 61, 'right') direction: right len beam 35
# step: 10000 beam: (70, 73, 'down') direction: down len beam 32
# step: 11000 beam: (50, 104, 'down') direction: down len beam 16
# calculating edge:  63 (0, 63, 'down') done, energized= 7867
# calculating edge:  64 (0, 64, 'down')
# calculating edge:  64 (0, 64, 'down') done, energized= 118
# calculating edge:  65 (0, 65, 'down')
# step: 1000 beam: (79, 20, 'right') direction: right len beam 12
# step: 2000 beam: (53, 41, 'up') direction: up len beam 31
# step: 3000 beam: (88, 85, 'up') direction: up len beam 35
# step: 4000 beam: (100, 72, 'left') direction: left len beam 39
# step: 5000 beam: (66, 56, 'up') direction: up len beam 40
# step: 6000 beam: (21, 41, 'right') direction: right len beam 36
# step: 7000 beam: (58, 54, 'up') direction: up len beam 44
# step: 8000 beam: (37, 88, 'right') direction: right len beam 34
# step: 9000 beam: (38, 46, 'left') direction: left len beam 37
# step: 10000 beam: (78, 107, 'right') direction: right len beam 29
# step: 11000 beam: (81, 68, 'right') direction: right len beam 17
# calculating edge:  65 (0, 65, 'down') done, energized= 7950
# calculating edge:  66 (0, 66, 'down')
# calculating edge:  66 (0, 66, 'down') done, energized= 89
# calculating edge:  67 (0, 67, 'down')
# step: 1000 beam: (49, 98, 'right') direction: right len beam 14
# step: 2000 beam: (62, 44, 'right') direction: right len beam 28
# step: 3000 beam: (97, 66, 'down') direction: down len beam 41
# step: 4000 beam: (66, 67, 'down') direction: down len beam 38
# step: 5000 beam: (50, 108, 'right') direction: right len beam 49
# step: 6000 beam: (15, 79, 'right') direction: right len beam 56
# step: 7000 beam: (93, 63, 'left') direction: left len beam 55
# step: 8000 beam: (31, 5, 'down') direction: down len beam 50
# step: 9000 beam: (39, 0, 'down') direction: down len beam 50
# step: 10000 beam: (-1, 69, 'up') direction: up len beam 34
# step: 11000 beam: (93, 81, 'down') direction: down len beam 19
# calculating edge:  67 (0, 67, 'down') done, energized= 7992
# calculating edge:  68 (0, 68, 'down')
# step: 1000 beam: (96, 87, 'down') direction: down len beam 13
# step: 2000 beam: (69, 94, 'up') direction: up len beam 28
# step: 3000 beam: (69, 65, 'down') direction: down len beam 28
# step: 4000 beam: (34, 91, 'down') direction: down len beam 42
# step: 5000 beam: (60, 55, 'down') direction: down len beam 48
# step: 6000 beam: (33, 34, 'left') direction: left len beam 47
# step: 7000 beam: (65, 103, 'down') direction: down len beam 45
# step: 8000 beam: (5, 36, 'right') direction: right len beam 42
# step: 9000 beam: (72, 27, 'up') direction: up len beam 32
# step: 10000 beam: (20, 30, 'right') direction: right len beam 25
# step: 11000 beam: (36, 67, 'right') direction: right len beam 15
# calculating edge:  68 (0, 68, 'down') done, energized= 7863
# calculating edge:  69 (0, 69, 'down')
# calculating edge:  69 (0, 69, 'down') done, energized= 47
# calculating edge:  70 (0, 70, 'down')
# calculating edge:  70 (0, 70, 'down') done, energized= 89
# calculating edge:  71 (0, 71, 'down')
# calculating edge:  71 (0, 71, 'down') done, energized= 44
# calculating edge:  72 (0, 72, 'down')
# step: 1000 beam: (49, 21, 'right') direction: right len beam 10
# step: 2000 beam: (61, 45, 'down') direction: down len beam 18
# step: 3000 beam: (78, 86, 'up') direction: up len beam 31
# step: 4000 beam: (69, 101, 'right') direction: right len beam 37
# step: 5000 beam: (62, 5, 'down') direction: down len beam 44
# step: 6000 beam: (54, 14, 'left') direction: left len beam 55
# step: 7000 beam: (104, 4, 'left') direction: left len beam 50
# step: 8000 beam: (59, 40, 'down') direction: down len beam 52
# step: 9000 beam: (60, 37, 'left') direction: left len beam 43
# step: 10000 beam: (51, 59, 'down') direction: down len beam 28
# step: 11000 beam: (110, 14, 'down') direction: down len beam 18
# calculating edge:  72 (0, 72, 'down') done, energized= 7855
# calculating edge:  73 (0, 73, 'down')
# calculating edge:  73 (0, 73, 'down') done, energized= 121
# calculating edge:  74 (0, 74, 'down')
# calculating edge:  74 (0, 74, 'down') done, energized= 66
# calculating edge:  75 (0, 75, 'down')
# step: 1000 beam: (29, 32, 'right') direction: right len beam 16
# step: 2000 beam: (38, 25, 'left') direction: left len beam 42
# step: 3000 beam: (27, 42, 'up') direction: up len beam 45
# step: 4000 beam: (47, 64, 'left') direction: left len beam 39
# step: 5000 beam: (64, 53, 'up') direction: up len beam 49
# step: 6000 beam: (53, 53, 'down') direction: down len beam 42
# step: 7000 beam: (63, 5, 'down') direction: down len beam 43
# step: 8000 beam: (93, 65, 'left') direction: left len beam 38
# step: 9000 beam: (71, 20, 'left') direction: left len beam 35
# step: 10000 beam: (102, 28, 'up') direction: up len beam 31
# step: 11000 beam: (19, 29, 'left') direction: left len beam 18
# calculating edge:  75 (0, 75, 'down') done, energized= 7981
# calculating edge:  76 (0, 76, 'down')
# calculating edge:  76 (0, 76, 'down') done, energized= 57
# calculating edge:  77 (0, 77, 'down')
# calculating edge:  77 (0, 77, 'down') done, energized= 106
# calculating edge:  78 (0, 78, 'down')
# step: 1000 beam: (66, 89, 'left') direction: left len beam 14
# step: 2000 beam: (81, 74, 'left') direction: left len beam 31
# step: 3000 beam: (78, 47, 'down') direction: down len beam 39
# step: 4000 beam: (78, 94, 'left') direction: left len beam 37
# step: 5000 beam: (90, 54, 'left') direction: left len beam 40
# step: 6000 beam: (95, 72, 'left') direction: left len beam 36
# step: 7000 beam: (51, 69, 'down') direction: down len beam 43
# step: 8000 beam: (104, 13, 'left') direction: left len beam 39
# step: 9000 beam: (62, 102, 'right') direction: right len beam 36
# step: 10000 beam: (30, 55, 'down') direction: down len beam 27
# step: 11000 beam: (10, 33, 'down') direction: down len beam 16
# calculating edge:  78 (0, 78, 'down') done, energized= 7887
# calculating edge:  79 (0, 79, 'down')
# calculating edge:  79 (0, 79, 'down') done, energized= 46
# calculating edge:  80 (0, 80, 'down')
# step: 1000 beam: (75, 21, 'up') direction: up len beam 14
# step: 2000 beam: (68, 52, 'down') direction: down len beam 31
# step: 3000 beam: (62, 85, 'right') direction: right len beam 39
# step: 4000 beam: (66, 86, 'right') direction: right len beam 37
# step: 5000 beam: (40, 44, 'left') direction: left len beam 40
# step: 6000 beam: (2, 30, 'left') direction: left len beam 37
# step: 7000 beam: (19, 54, 'left') direction: left len beam 43
# step: 8000 beam: (53, 76, 'right') direction: right len beam 37
# step: 9000 beam: (52, 90, 'down') direction: down len beam 36
# step: 10000 beam: (21, 92, 'down') direction: down len beam 27
# step: 11000 beam: (96, 51, 'up') direction: up len beam 17
# calculating edge:  80 (0, 80, 'down') done, energized= 7892
# calculating edge:  81 (0, 81, 'down')
# step: 1000 beam: (30, 55, 'left') direction: left len beam 18
# step: 2000 beam: (33, 98, 'down') direction: down len beam 41
# step: 3000 beam: (52, 45, 'up') direction: up len beam 45
# step: 4000 beam: (11, 34, 'left') direction: left len beam 40
# step: 5000 beam: (75, 26, 'up') direction: up len beam 47
# step: 6000 beam: (49, 26, 'right') direction: right len beam 38
# step: 7000 beam: (68, 53, 'down') direction: down len beam 45
# step: 8000 beam: (47, 0, 'left') direction: left len beam 40
# step: 9000 beam: (63, 107, 'right') direction: right len beam 34
# step: 10000 beam: (23, 5, 'right') direction: right len beam 34
# step: 11000 beam: (19, 24, 'left') direction: left len beam 18
# calculating edge:  81 (0, 81, 'down') done, energized= 7980
# calculating edge:  82 (0, 82, 'down')
# step: 1000 beam: (33, 81, 'up') direction: up len beam 21
# step: 2000 beam: (47, 66, 'down') direction: down len beam 22
# step: 3000 beam: (49, 74, 'left') direction: left len beam 41
# step: 4000 beam: (76, 55, 'down') direction: down len beam 52
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 46
#      43             traced_beams.append(next_beam)
#      44             beams.append(next_beam)
# ---> 46     current_energized = count_number_of_non_zero(energized)
#      47     # print("current energized: " + str(current_energized), "last energized: " + str(last_energized))
#      49 edge_energized.append(current_energized)
#
# Cell In[24], line 5, in count_number_of_non_zero(energized)
#       3 for row in range(len(energized)):
#       4     for col in range(len(energized[row])):
# ----> 5         if energized[row][col] != 0:
#       6             count += 1
#       7 return count
#
# KeyboardInterrupt:

# %%
max(edge_energized)
# Out:
# 51

# %%
## offline, split into 4 script and run in parallel

# %%
edge_start_beams = []
# top
if sys.argv[1] == "0":
    for idx in range(len(pattern[0])):
        edge_start_beams.append((0, idx, "down"))
# bottom
elif sys.argv[1] == "1":
    for idx in range(len(pattern[-1])):
        edge_start_beams.append((len(pattern) - 1, idx, "up"))
# left
elif sys.argv[1] == "2":
    for idx in range(len(pattern)):
        edge_start_beams.append((idx, 0, "right"))
# right
elif sys.argv[1] == "3":
    for idx in range(len(pattern)):
        edge_start_beams.append((idx, len(pattern[0]) - 1, "left"))
